# %%
# !git clone https://github.com/gangulypritha/UI2Code.git
# Out:
# Cloning into 'UI2Code'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 40 (delta 13), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (40/40), 18.19 KiB | 1.30 MiB/s, done.

# %%
cd UI2Code
# Out:
# /content/UI2Code

# %%
# !cp /content/drive/MyDrive/PCS_Assignment/UI2Code/data.zip .

# %%
# !unzip data.zip

# %%
# !pip install -r requirements.txt

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python split_data.py --data_path=./data/D1/input
# Out:
# Found a total of 300 valid examples

# %%
# !python split_data.py --data_path=./data/D2/input
# Out:
# Found a total of 300 valid examples

# %%
# !python split_data.py --data_path=./data/D3/input
# Out:
# Found a total of 300 valid examples

# %%
# !python build_vocab.py --data_path=./data/D1/input
# Out:
# Writing vocab with 15 tokens

# %%
# !python build_vocab.py --data_path=./data/D2/input
# Out:
# Writing vocab with 28 tokens

# %%
# !python build_vocab.py --data_path=./data/D3/input
# Out:
# Writing vocab with 30 tokens

# %%
# !python train.py --data_path=./data/D1/input --epochs=50 --save_after_epochs=10 --batch_size=4 --split=train --models_dir=./models/D1/
# Out:
# Training args: Namespace(data_path='./data/D1/input', cuda=True, img_crop_size=224, embed_size=256, hidden_size=512, num_layers=1, split='train', save_after_epochs=10, models_dir='./models/D1/', batch_size=4, epochs=50, lr=0.001, print_freq=1, seed=2020)
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Created data loader
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
# !python train.py --data_path=./data/D2/input --epochs=50 --save_after_epochs=10 --batch_size=4 --split=train --models_dir=./models/D2/
# Out:
# Training args: Namespace(data_path='./data/D2/input', cuda=True, img_crop_size=224, embed_size=256, hidden_size=512, num_layers=1, split='train', save_after_epochs=10, models_dir='./models/D2/', batch_size=4, epochs=50, lr=0.001, print_freq=1, seed=2020)
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Created data loader
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
# !python train.py --data_path=./data/D3/input --epochs=50 --save_after_epochs=10 --batch_size=4 --split=train --models_dir=./models/D3/
# Out:
# Training args: Namespace(data_path='./data/D3/input', cuda=True, img_crop_size=224, embed_size=256, hidden_size=512, num_layers=1, split='train', save_after_epochs=10, models_dir='./models/D3/', batch_size=4, epochs=50, lr=0.001, print_freq=1, seed=2020)
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Created data loader
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
# !python evaluate.py --data_path=./data/D1/input --model_file_path=./models/D1/model--epoch-49.pth --split=test --viz_file_name=D1_with_D1.pkl
# Out:
# Evaluation args: Namespace(model_file_path='./models/D1/model--epoch-49.pth', data_path='./data/D1/input', cuda=True, img_crop_size=224, embed_size=256, hidden_size=512, num_layers=1, split='test', batch_size=4, viz_file_name='D1_with_D1.pkl', seed=2020)
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# !python evaluate.py --data_path=./data/D2/input --model_file_path=./models/D2/model--epoch-49.pth --split=test --viz_file_name=D2_with_D2.pkl
# Out:
# Evaluation args: Namespace(model_file_path='./models/D2/model--epoch-49.pth', data_path='./data/D2/input', cuda=True, img_crop_size=224, embed_size=256, hidden_size=512, num_layers=1, split='test', batch_size=4, viz_file_name='D2_with_D2.pkl', seed=2020)
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# !python evaluate.py --data_path=./data/D3/input --model_file_path=./models/D3/model--epoch-49.pth --split=test --viz_file_name=D3_with_D3.pkl
# Out:
# Evaluation args: Namespace(model_file_path='./models/D3/model--epoch-49.pth', data_path='./data/D3/input', cuda=True, img_crop_size=224, embed_size=256, hidden_size=512, num_layers=1, split='test', batch_size=4, viz_file_name='D3_with_D3.pkl', seed=2020)
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# !python evaluate.py --data_path=./data/D1/input --model_file_path=./models/D3/model--epoch-49.pth --split=test --viz_file_name=D1_with_D3.pkl
# Out:
# Evaluation args: Namespace(model_file_path='./models/D3/model--epoch-49.pth', data_path='./data/D1/input', cuda=True, img_crop_size=224, embed_size=256, hidden_size=512, num_layers=1, split='test', batch_size=4, viz_file_name='D1_with_D3.pkl', seed=2020)
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# !python evaluate.py --data_path=./data/D1/input --model_file_path=./models/D2/model--epoch-49.pth --split=test --viz_file_name=D1_with_D2.pkl
# Out:
# Evaluation args: Namespace(model_file_path='./models/D2/model--epoch-49.pth', data_path='./data/D1/input', cuda=True, img_crop_size=224, embed_size=256, hidden_size=512, num_layers=1, split='test', batch_size=4, viz_file_name='D1_with_D2.pkl', seed=2020)
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# !python evaluate.py --data_path=./data/D2/input --model_file_path=./models/D3/model--epoch-49.pth --split=test --viz_file_name=D2_with_D3.pkl
# Out:
# Evaluation args: Namespace(model_file_path='./models/D3/model--epoch-49.pth', data_path='./data/D2/input', cuda=True, img_crop_size=224, embed_size=256, hidden_size=512, num_layers=1, split='test', batch_size=4, viz_file_name='D2_with_D3.pkl', seed=2020)
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# !python evaluate.py --data_path=./data/D2/input --model_file_path=./models/D1/model--epoch-49.pth --split=test --viz_file_name=D2_with_D1.pkl
# Out:
# Evaluation args: Namespace(model_file_path='./models/D1/model--epoch-49.pth', data_path='./data/D2/input', cuda=True, img_crop_size=224, embed_size=256, hidden_size=512, num_layers=1, split='test', batch_size=4, viz_file_name='D2_with_D1.pkl', seed=2020)
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# !python evaluate.py --data_path=./data/D3/input --model_file_path=./models/D1/model--epoch-49.pth --split=test --viz_file_name=D3_with_D1.pkl
# Out:
# Evaluation args: Namespace(model_file_path='./models/D1/model--epoch-49.pth', data_path='./data/D3/input', cuda=True, img_crop_size=224, embed_size=256, hidden_size=512, num_layers=1, split='test', batch_size=4, viz_file_name='D3_with_D1.pkl', seed=2020)
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# !python evaluate.py --data_path=./data/D3/input --model_file_path=./models/D2/model--epoch-49.pth --split=test --viz_file_name=D3_with_D2.pkl
# Out:
# Evaluation args: Namespace(model_file_path='./models/D2/model--epoch-49.pth', data_path='./data/D3/input', cuda=True, img_crop_size=224, embed_size=256, hidden_size=512, num_layers=1, split='test', batch_size=4, viz_file_name='D3_with_D2.pkl', seed=2020)
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...
